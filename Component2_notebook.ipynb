# %%
import sys
import os
from neo4j import GraphDatabase


sys.path.append(os.path.abspath("."))


def load_config():
    cfg = {}
    with open("config.txt", "r") as f:
        for line in f:
            if "=" in line:
                k, v = line.strip().split("=")
                cfg[k] = v
    return cfg

config = load_config()

URI = config["URI"]
USERNAME = config["USERNAME"]
PASSWORD = config["PASSWORD"]

# %%
from graph_retriever import GraphRetriever

# %%
gr = GraphRetriever(URI, USERNAME, PASSWORD)

print("GraphRetriever initialized.")
# Out:
# GraphRetriever initialized.

# %% [markdown]
# ## Baseline Retrieval Example

# %%
result = gr.retrieve("flights_from", {"origin": "MEX"})
result
# Out:
# [{'flight': '4709', 'origin': 'MEX'},
#  {'flight': '1839', 'origin': 'MEX'},
#  {'flight': '5565', 'origin': 'MEX'},
#  {'flight': '475', 'origin': 'MEX'},
#  {'flight': '429', 'origin': 'MEX'},
#  {'flight': '2330', 'origin': 'MEX'},
#  {'flight': '2253', 'origin': 'MEX'},
#  {'flight': '62', 'origin': 'MEX'},
#  {'flight': '445', 'origin': 'MEX'},
#  {'flight': '1065', 'origin': 'MEX'},
#  {'flight': '1090', 'origin': 'MEX'},
#  {'flight': '833', 'origin': 'MEX'}]

# %%
result = gr.retrieve("flights_to", {"destination": "IAX"})
result
# Out:
# [{'flight': '500', 'destination': 'IAX'},
#  {'flight': '128', 'destination': 'IAX'},
#  {'flight': '298', 'destination': 'IAX'},
#  {'flight': '1469', 'destination': 'IAX'},
#  {'flight': '614', 'destination': 'IAX'},
#  {'flight': '6131', 'destination': 'IAX'},
#  {'flight': '1046', 'destination': 'IAX'},
#  {'flight': '880', 'destination': 'IAX'},
#  {'flight': '1496', 'destination': 'IAX'},
#  {'flight': '6112', 'destination': 'IAX'},
#  {'flight': '984', 'destination': 'IAX'},
#  {'flight': '1282', 'destination': 'IAX'},
#  {'flight': '1902', 'destination': 'IAX'},
#  {'flight': '1891', 'destination': 'IAX'},
#  {'flight': '1414', 'destination': 'IAX'},
#  {'flight': '2244', 'destination': 'IAX'},
#  {'flight': '780', 'destination': 'IAX'},
#  {'flight': '2373', 'destination': 'IAX'},
#  {'flight': '6315', 'destination': 'IAX'},
#  {'flight': '1930', 'destination': 'IAX'},
#  {'flight': '5', 'destination': 'IAX'},
#  {'flight': '1765', 'destination': 'IAX'},
#  {'flight': '462', 'destination': 'IAX'},
#  {'flight': '253', 'destination': 'IAX'},
#  {'flight': '2380', 'destination': 'IAX'},
#  {'flight': '1696', 'destination': 'IAX'},
#  {'flight': '6017', 'destination': 'IAX'},
#  {'flight': '2130', 'destination': 'IAX'},
#  {'flight': '5369', 'destination': 'IAX'},
#  {'flight': '1224', 'destination': 'IAX'},
#  {'flight': '1100', 'destination': 'IAX'},
#  {'flight': '2003', 'destination': 'IAX'},
#  {'flight': '470', 'destination': 'IAX'},
#  {'flight': '1974', 'destination': 'IAX'},
#  {'flight': '1653', 'destination': 'IAX'},
#  {'flight': '2102', 'destination': 'IAX'},
#  {'flight': '915', 'destination': 'IAX'},
#  {'flight': '1501', 'destination': 'IAX'},
#  {'flight': '952', 'destination': 'IAX'},
#  {'flight': '2196', 'destination': 'IAX'},
#  {'flight': '2385', 'destination': 'IAX'},
#  {'flight': '64', 'destination': 'IAX'},
#  {'flight': '1969', 'destination': 'IAX'},
#  {'flight': '2607', 'destination': 'IAX'},
#  {'flight': '1715', 'destination': 'IAX'},
#  {'flight': '998', 'destination': 'IAX'},
#  {'flight': '1463', 'destination': 'IAX'},
#  {'flight': '435', 'destination': 'IAX'},
#  {'flight': '1947', 'destination': 'IAX'},
#  {'flight': '6159', 'destination': 'IAX'},
#  {'flight': '2264', 'destination': 'IAX'},
#  {'flight': '1941', 'destination': 'IAX'},
#  {'flight': '920', 'destination': 'IAX'},
#  {'flight': '129', 'destination': 'IAX'},
#  {'flight': '1760', 'destination': 'IAX'},
#  {'flight': '6052', 'destination': 'IAX'},
#  {'flight': '1839', 'destination': 'IAX'},
#  {'flight': '6085', 'destination': 'IAX'},
#  {'flight': '388', 'destination': 'IAX'},
#  {'flight': '54', 'destination': 'IAX'},
#  {'flight': '2102', 'destination': 'IAX'},
#  {'flight': '625', 'destination': 'IAX'},
#  {'flight': '2283', 'destination': 'IAX'},
#  {'flight': '379', 'destination': 'IAX'},
#  {'flight': '1655', 'destination': 'IAX'},
#  {'flight': '2611', 'destination': 'IAX'},
#  {'flight': '984', 'destination': 'IAX'},
#  {'flight': '1778', 'destination': 'IAX'},
#  {'flight': '2084', 'destination': 'IAX'},
#  {'flight': '1914', 'destination': 'IAX'},
#  {'flight': '161', 'destination': 'IAX'},
#  {'flight': '392', 'destination': 'IAX'},
#  {'flight': '2141', 'destination': 'IAX'},
#  {'flight': '1735', 'destination': 'IAX'},
#  {'flight': '74', 'destination': 'IAX'},
#  {'flight': '2627', 'destination': 'IAX'},
#  {'flight': '1591', 'destination': 'IAX'},
#  {'flight': '1262', 'destination': 'IAX'},
#  {'flight': '4395', 'destination': 'IAX'},
#  {'flight': '108', 'destination': 'IAX'},
#  {'flight': '4393', 'destination': 'IAX'},
#  {'flight': '2300', 'destination': 'IAX'},
#  {'flight': '2391', 'destination': 'IAX'},
#  {'flight': '594', 'destination': 'IAX'},
#  {'flight': '2234', 'destination': 'IAX'},
#  {'flight': '2673', 'destination': 'IAX'},
#  {'flight': '527', 'destination': 'IAX'},
#  {'flight': '6363', 'destination': 'IAX'},
#  {'flight': '2171', 'destination': 'IAX'},
#  {'flight': '1610', 'destination': 'IAX'},
#  {'flight': '786', 'destination': 'IAX'},
#  {'flight': '1852', 'destination': 'IAX'},
#  {'flight': '377', 'destination': 'IAX'},
#  {'flight': '2211', 'destination': 'IAX'},
#  {'flight': '6148', 'destination': 'IAX'},
#  {'flight': '2499', 'destination': 'IAX'},
#  {'flight': '6229', 'destination': 'IAX'},
#  {'flight': '1276', 'destination': 'IAX'},
#  {'flight': '2166', 'destination': 'IAX'},
#  {'flight': '1243', 'destination': 'IAX'},
#  {'flight': '128', 'destination': 'IAX'},
#  {'flight': '2251', 'destination': 'IAX'},
#  {'flight': '1563', 'destination': 'IAX'},
#  {'flight': '1482', 'destination': 'IAX'},
#  {'flight': '1713', 'destination': 'IAX'},
#  {'flight': '6152', 'destination': 'IAX'},
#  {'flight': '1636', 'destination': 'IAX'},
#  {'flight': '6137', 'destination': 'IAX'},
#  {'flight': '345', 'destination': 'IAX'},
#  {'flight': '1142', 'destination': 'IAX'},
#  {'flight': '980', 'destination': 'IAX'},
#  {'flight': '1789', 'destination': 'IAX'},
#  {'flight': '1428', 'destination': 'IAX'},
#  {'flight': '512', 'destination': 'IAX'},
#  {'flight': '2620', 'destination': 'IAX'},
#  {'flight': '2068', 'destination': 'IAX'},
#  {'flight': '1446', 'destination': 'IAX'},
#  {'flight': '494', 'destination': 'IAX'},
#  {'flight': '2137', 'destination': 'IAX'},
#  {'flight': '383', 'destination': 'IAX'},
#  {'flight': '706', 'destination': 'IAX'},
#  {'flight': '1702', 'destination': 'IAX'},
#  {'flight': '530', 'destination': 'IAX'},
#  {'flight': '513', 'destination': 'IAX'},
#  {'flight': '1996', 'destination': 'IAX'},
#  {'flight': '6184', 'destination': 'IAX'},
#  {'flight': '1649', 'destination': 'IAX'},
#  {'flight': '1841', 'destination': 'IAX'},
#  {'flight': '1702', 'destination': 'IAX'},
#  {'flight': '2380', 'destination': 'IAX'},
#  {'flight': '2322', 'destination': 'IAX'},
#  {'flight': '1756', 'destination': 'IAX'},
#  {'flight': '784', 'destination': 'IAX'},
#  {'flight': '1845', 'destination': 'IAX'},
#  {'flight': '2058', 'destination': 'IAX'},
#  {'flight': '1118', 'destination': 'IAX'},
#  {'flight': '488', 'destination': 'IAX'},
#  {'flight': '612', 'destination': 'IAX'},
#  {'flight': '2134', 'destination': 'IAX'},
#  {'flight': '2429', 'destination': 'IAX'},
#  {'flight': '2359', 'destination': 'IAX'},
#  {'flight': '5473', 'destination': 'IAX'},
#  {'flight': '1246', 'destination': 'IAX'},
#  {'flight': '429', 'destination': 'IAX'},
#  {'flight': '420', 'destination': 'IAX'},
#  {'flight': '2295', 'destination': 'IAX'},
#  {'flight': '275', 'destination': 'IAX'},
#  {'flight': '1591', 'destination': 'IAX'},
#  {'flight': '2283', 'destination': 'IAX'},
#  {'flight': '1448', 'destination': 'IAX'},
#  {'flight': '1158', 'destination': 'IAX'},
#  {'flight': '2283', 'destination': 'IAX'},
#  {'flight': '6039', 'destination': 'IAX'},
#  {'flight': '2629', 'destination': 'IAX'},
#  {'flight': '306', 'destination': 'IAX'},
#  {'flight': '1028', 'destination': 'IAX'},
#  {'flight': '2399', 'destination': 'IAX'},
#  {'flight': '669', 'destination': 'IAX'},
#  {'flight': '2197', 'destination': 'IAX'},
#  {'flight': '2276', 'destination': 'IAX'},
#  {'flight': '2330', 'destination': 'IAX'},
#  {'flight': '1670', 'destination': 'IAX'},
#  {'flight': '344', 'destination': 'IAX'},
#  {'flight': '1087', 'destination': 'IAX'},
#  {'flight': '6025', 'destination': 'IAX'},
#  {'flight': '297', 'destination': 'IAX'},
#  {'flight': '2229', 'destination': 'IAX'},
#  {'flight': '1607', 'destination': 'IAX'},
#  {'flight': '1962', 'destination': 'IAX'},
#  {'flight': '2276', 'destination': 'IAX'},
#  {'flight': '2160', 'destination': 'IAX'},
#  {'flight': '3407', 'destination': 'IAX'},
#  {'flight': '6081', 'destination': 'IAX'},
#  {'flight': '1746', 'destination': 'IAX'},
#  {'flight': '1681', 'destination': 'IAX'},
#  {'flight': '6042', 'destination': 'IAX'},
#  {'flight': '22', 'destination': 'IAX'},
#  {'flight': '1018', 'destination': 'IAX'},
#  {'flight': '2391', 'destination': 'IAX'},
#  {'flight': '4741', 'destination': 'IAX'},
#  {'flight': '2289', 'destination': 'IAX'},
#  {'flight': '1262', 'destination': 'IAX'},
#  {'flight': '3019', 'destination': 'IAX'},
#  {'flight': '653', 'destination': 'IAX'},
#  {'flight': '5240', 'destination': 'IAX'},
#  {'flight': '2276', 'destination': 'IAX'},
#  {'flight': '307', 'destination': 'IAX'},
#  {'flight': '6105', 'destination': 'IAX'},
#  {'flight': '2162', 'destination': 'IAX'},
#  {'flight': '513', 'destination': 'IAX'},
#  {'flight': '488', 'destination': 'IAX'},
#  {'flight': '207', 'destination': 'IAX'},
#  {'flight': '6154', 'destination': 'IAX'},
#  {'flight': '6051', 'destination': 'IAX'},
#  {'flight': '339', 'destination': 'IAX'},
#  {'flight': '506', 'destination': 'IAX'},
#  {'flight': '1414', 'destination': 'IAX'},
#  {'flight': '2058', 'destination': 'IAX'},
#  {'flight': '1168', 'destination': 'IAX'},
#  {'flight': '6074', 'destination': 'IAX'},
#  {'flight': '1182', 'destination': 'IAX'},
#  {'flight': '2262', 'destination': 'IAX'},
#  {'flight': '2666', 'destination': 'IAX'},
#  {'flight': '2281', 'destination': 'IAX'},
#  {'flight': '992', 'destination': 'IAX'},
#  {'flight': '2088', 'destination': 'IAX'},
#  {'flight': '6101', 'destination': 'IAX'},
#  {'flight': '1746', 'destination': 'IAX'},
#  {'flight': '3504', 'destination': 'IAX'},
#  {'flight': '5878', 'destination': 'IAX'},
#  {'flight': '2137', 'destination': 'IAX'},
#  {'flight': '1607', 'destination': 'IAX'},
#  {'flight': '6077', 'destination': 'IAX'},
#  {'flight': '6134', 'destination': 'IAX'},
#  {'flight': '476', 'destination': 'IAX'},
#  {'flight': '5338', 'destination': 'IAX'},
#  {'flight': '6178', 'destination': 'IAX'},
#  {'flight': '6048', 'destination': 'IAX'},
#  {'flight': '1016', 'destination': 'IAX'},
#  {'flight': '1090', 'destination': 'IAX'},
#  {'flight': '934', 'destination': 'IAX'},
#  {'flight': '422', 'destination': 'IAX'},
#  {'flight': '251', 'destination': 'IAX'},
#  {'flight': '1437', 'destination': 'IAX'},
#  {'flight': '1908', 'destination': 'IAX'},
#  {'flight': '2411', 'destination': 'IAX'},
#  {'flight': '659', 'destination': 'IAX'},
#  {'flight': '48', 'destination': 'IAX'},
#  {'flight': '989', 'destination': 'IAX'},
#  {'flight': '2171', 'destination': 'IAX'},
#  {'flight': '2066', 'destination': 'IAX'},
#  {'flight': '926', 'destination': 'IAX'},
#  {'flight': '992', 'destination': 'IAX'},
#  {'flight': '944', 'destination': 'IAX'},
#  {'flight': '1870', 'destination': 'IAX'},
#  {'flight': '1059', 'destination': 'IAX'},
#  {'flight': '819', 'destination': 'IAX'},
#  {'flight': '1416', 'destination': 'IAX'},
#  {'flight': '2608', 'destination': 'IAX'},
#  {'flight': '688', 'destination': 'IAX'},
#  {'flight': '405', 'destination': 'IAX'},
#  {'flight': '2066', 'destination': 'IAX'},
#  {'flight': '1165', 'destination': 'IAX'},
#  {'flight': '3582', 'destination': 'IAX'},
#  {'flight': '1406', 'destination': 'IAX'},
#  {'flight': '886', 'destination': 'IAX'},
#  {'flight': '1868', 'destination': 'IAX'},
#  {'flight': '3531', 'destination': 'IAX'},
#  {'flight': '856', 'destination': 'IAX'},
#  {'flight': '2190', 'destination': 'IAX'},
#  {'flight': '2493', 'destination': 'IAX'},
#  {'flight': '2622', 'destination': 'IAX'},
#  {'flight': '1632', 'destination': 'IAX'},
#  {'flight': '6033', 'destination': 'IAX'},
#  {'flight': '6116', 'destination': 'IAX'},
#  {'flight': '1517', 'destination': 'IAX'},
#  {'flight': '1194', 'destination': 'IAX'},
#  {'flight': '1460', 'destination': 'IAX'},
#  {'flight': '1619', 'destination': 'IAX'},
#  {'flight': '751', 'destination': 'IAX'},
#  {'flight': '509', 'destination': 'IAX'}]

# %%
result = gr.retrieve("journey_flight", {"feedback_id": "F_1"})
result
# Out:
# [{'journey_id': 'F_1', 'flight': '2411'}]

# %%
result = gr.retrieve("flights_between",
                     {"origin": "MEX", "destination": "IAX"})
result
# Out:
# [{'flight': '1839'}, {'flight': '429'}, {'flight': '2330'}, {'flight': '1090'}]

# %% [markdown]
# ## Train Node2Vec Embeddings

# %%
print("Training Node2Vec embeddings...")
output = gr.build_embeddings(method="node2vec")
output
# Out:
# Training Node2Vec embeddings...
# Computing transition probabilities:   0%|          | 0/7944 [00:00<?, ?it/s]
# Generating walks (CPU: 1): 100%|██████████| 25/25 [00:00<00:00, 35.79it/s]
# Generating walks (CPU: 2): 100%|██████████| 25/25 [00:00<00:00, 36.07it/s]
# "Embedding model 'node2vec_embed' trained and indexed."

# %% [markdown]
# ## Train GraphSAGE Embeddings

# %%
print("Training GraphSAGE embeddings...")
output = gr.build_embeddings(method="graphsage")
output
# Out:
# Training GraphSAGE embeddings...
# "Embedding model 'sage_embed' trained and indexed."

# %% [markdown]
# ## Similarity Search Example

# %%
with gr.driver.session() as session:
    eid = session.run("""
        MATCH (p:Passenger)
        RETURN elementId(p) AS eid
        LIMIT 1
    """).single()["eid"]

eid
# Out:
# '4:5db1414e-a7ed-4877-a4a1-3456bfe83c2f:0'

# %%
print("Node2Vec similarity search (Passenger):")

result = gr.retrieve(
    "similar_nodes",
    {
        "embedding_name": "node2vec_embed",
        "label": "Passenger",
        "node_eid": eid,
        "k": 5
    }
)

result
# Out:
# Node2Vec similarity search (Passenger):
# [{'id': '4:5db1414e-a7ed-4877-a4a1-3456bfe83c2f:0',
#   'score': 0.9999357461929321},
#  {'id': '4:5db1414e-a7ed-4877-a4a1-3456bfe83c2f:3567',
#   'score': 0.9911239147186279},
#  {'id': '4:5db1414e-a7ed-4877-a4a1-3456bfe83c2f:3139',
#   'score': 0.990331768989563},
#  {'id': '4:5db1414e-a7ed-4877-a4a1-3456bfe83c2f:3017',
#   'score': 0.9903204441070557},
#  {'id': '4:5db1414e-a7ed-4877-a4a1-3456bfe83c2f:7099',
#   'score': 0.9902714490890503}]

# %%
print("GraphSAGE similarity search (Passenger):")

result = gr.retrieve(
    "similar_nodes",
    {
        "embedding_name": "sage_embed",
        "label": "Passenger",
        "node_eid": eid,
        "k": 5
    }
)

result
# Out:
# GraphSAGE similarity search (Passenger):
# [{'id': '4:5db1414e-a7ed-4877-a4a1-3456bfe83c2f:0',
#   'score': 0.9997367858886719},
#  {'id': '4:5db1414e-a7ed-4877-a4a1-3456bfe83c2f:8241',
#   'score': 0.9977693557739258},
#  {'id': '4:5db1414e-a7ed-4877-a4a1-3456bfe83c2f:7059',
#   'score': 0.9976536631584167},
#  {'id': '4:5db1414e-a7ed-4877-a4a1-3456bfe83c2f:4608',
#   'score': 0.9973176121711731},
#  {'id': '4:5db1414e-a7ed-4877-a4a1-3456bfe83c2f:2454',
#   'score': 0.997127890586853}]
